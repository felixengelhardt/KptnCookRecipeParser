# %%
import json

# %%
rawString = open("kptncook_1.json","r").read()

# %%
recipeCollection = json.loads(rawString)

# %%
recipeCollection[0]
# Out:
# {'date': '2024-08-21',
#  'data': {'_id': {'$oid': '5f11c4a8fb000081ef54bc80'},
#   'localizedTitle': {'en': 'Garlic & Ginger Glazed Pork',
#    'de': 'Scharf glasiertes Schweinefilet',
#    'es': 'Filete de cerdo glaseado con ajo y jengibre',
#    'fr': "Porc glacé à l'ail et au gingembre",
#    'pt': 'Carne de porco glaceada com alho e gengibre'},
#   'rtype': 'Pork',
#   'gdocs': '1995',
#   'authorComment': {'en': "Get your fork, I'll make delicious pork",
#    'de': 'Für Fleisch-Fans unumgehbar',
#    'es': '¡Con este filete glaseado, quedarás fascinado!',
#    'fr': 'À vos couverts\xa0!',
#    'pt': 'Cometi um ato (f)alho!'},
#   'uid': '149223ab',
#   'preparationTime': 30,
#   'cookingTime': 0,
#   'recipeNutrition': {'calories': 784,
#    'protein': 43,
#    'fat': 31,
#    'carbohydrate': 82},
#   'activeTags': ['main_ingredient_pork',
#    'diet_lactose_free',
#    'asian_fusion',
#    'under_five_ingredient',
#    'spring',
#    'comfort_foot',
#    'budget_under_7_de',
# ...

# %%
recipeCollection[0].keys()
# Out:
# dict_keys(['date', 'data'])

# %%
recipeCollection[0]["data"].keys()
# Out:
# dict_keys(['_id', 'localizedTitle', 'rtype', 'gdocs', 'authorComment', 'uid', 'preparationTime', 'cookingTime', 'recipeNutrition', 'activeTags', 'steps', 'authors', 'retailers', 'ingredients', 'imageList', 'trackingMode', 'feature', 'ingredientTags', 'favoriteCount', 'creationDate', 'updateDate'])

# %%
recipeCollection[0]["data"]["localizedTitle"]["de"]
# Out:
# 'Scharf glasiertes Schweinefilet'

# %%
recipeCollection[0]["data"]["ingredients"][3]
# Out:
# {'quantity': 2,
#  'measure': 'EL',
#  'quantityProd': 30,
#  'quantityUS': 0.125,
#  'measureUS': 'cup(s)',
#  'quantityUSProd': 1.5,
#  'measureUSProd': 'oz',
#  'ingredient': {'_id': {'$oid': '626a432f51000052068ccf55'},
#   'typ': 'basic',
#   'localizedTitle': {'en': 'honey',
#    'de': 'Honig',
#    'es': 'miel',
#    'fr': 'miel',
#    'pt': 'mel'},
#   'numberTitle': {'singular': {'en': 'honey',
#     'de': 'Honig',
#     'es': 'miel',
#     'fr': 'miel',
#     'pt': 'mel'},
#    'plural': {'en': 'honey',
#     'de': 'Honig',
#     'es': 'miel',
#     'fr': 'miel',
#     'pt': 'mel'}},
#   'uncountableTitle': {'en': 'honey',
#    'de': 'Honig',
#    'es': 'miel',
#    'fr': 'miel',
#    'pt': 'mel'},
#   'category': 'Breakfast',
#   'key': 'honeyhonighoneyhonig',
#   'desc': 'honeyhonighoneyhonig',
#   'image': {'name': 'pantry_honey_s.jpg',
#    'url': 'https://images.kptncook.com/626a434a4e00002006020898.jpg'},
#   'products': [{'_id': {'$oid': '628e2359860000c0001d51bd'},
# ...
